# %%
import ufal.udpipe
from ufal.udpipe import Trainer, Evaluator
import os
import conllu

# %%
#Implementing a processing pipeline, which inclides tokenization, morphological tagging and syntactic parsing
#Source: https://github.com/ufal/udpipe/tree/master/bindings/python/examples

class Model:
    def __init__(self, model):
        """Load given model."""
        self.model = model
        if not self.model:
            raise Exception("Cannot load UDPipe model from file '%s'" % model)

    def tokenize(self, text):
        """Tokenize the text and return list of ufal.udpipe.Sentence-s."""
        tokenizer = self.model.newTokenizer(self.model.DEFAULT)
        if not tokenizer:
            raise Exception("The model does not have a tokenizer")
        return self._read(text, tokenizer)

    def read(self, text, format):
        """Load text in the given format (conllu|horizontal|vertical) and return list of ufal.udpipe.Sentence-s."""
        input_format = ufal.udpipe.InputFormat.newInputFormat(format)
        if not input_format:
            raise Exception("Cannot create input format '%s'" % format)
        return self._read(text, input_format)

    def _read(self, text, input_format):
        input_format.setText(text)
        error = ufal.udpipe.ProcessingError()
        sentences = []

        sentence = ufal.udpipe.Sentence()
        while input_format.nextSentence(sentence, error):
            sentences.append(sentence)
            sentence = ufal.udpipe.Sentence()
        if error.occurred():
            raise Exception(error.message)

        return sentences

    def tag(self, sentence):
        """Tag the given ufal.udpipe.Sentence (inplace)."""
        self.model.tag(sentence, self.model.DEFAULT)

    def parse(self, sentence):
        """Parse the given ufal.udpipe.Sentence (inplace)."""
        self.model.parse(sentence, self.model.DEFAULT)

    def write(self, sentences, format):
        """Write given ufal.udpipe.Sentence-s in the required format (conllu|horizontal|vertical)."""

        output_format = ufal.udpipe.OutputFormat.newOutputFormat(format)
        output = ''
        for sentence in sentences:
            output += output_format.writeSentence(sentence)
        output += output_format.finishDocument()
        return output
    
def process(raw_model, text):
    model = Model(raw_model)
    sentences = model.tokenize(text)
    for sent in sentences:
        model.tag(sent)
        model.parse(sent)
    output = model.write(sentences, "conllu")
    return output

# %% [markdown]
# ### Обучение моделей и определение их метрик проводилось с помощью скомпилированной версии udpipe. Код:
#
# udpipe --train projective.udpipe UD_Russian-SynTagRus/ru_syntagrus-ud-train-short.conllu --tokenizer epochs=10 --tagger iterations=10 --parser iterations=10;transition_system=projective
#
# udpipe --train swap.output UD_Russian-SynTagRus/ru_syntagrus-ud-train-short.conllu --tokenizer epochs=10 --tagger iterations=10 --parser iterations=10;transition_system=swap
#
# udpipe --train link2.output UD_Russian-SynTagRus/ru_syntagrus-ud-train-short.conllu --tokenizer epochs=10 --tagger iterations=10 --parser iterations=10;transition_system=link2
#
# udpipe --accuracy --parse projective.output UD_Russian-SynTagRus/ru_syntagrus-ud-dev.conllu
#
# udpipe --accuracy --parse swap.output UD_Russian-SynTagRus/ru_syntagrus-ud-dev.conllu
#
# udpipe --accuracy --parse link2.output UD_Russian-SynTagRus/ru_syntagrus-ud-dev.conllu

# %%
#Parsing the test text using the models trained on 2018 data

model_projective = ufal.udpipe.Model.load('projective.output')
model_swap = ufal.udpipe.Model.load('swap.output')
model_link2 = ufal.udpipe.Model.load('link2.output')

# %%
with open('UD_Russian-SynTagRus/ru_syntagrus-ud-dev.txt', 'r', encoding = 'utf-8') as f:
    input_text = f.read()[:10000]
    parsed_projective = process(model_projective, input_text)
    print('done with projective parsing')
    parsed_swap = process(model_swap, input_text)
    print('done with swap parsing')
    parsed_link2 = process(model_link2, input_text)
    print('done with link2 parsing')
# Out:
# done with projective parsing
# done with swap parsing
# done with link2 parsing

# %%
proj_conll = conllu.parse(parsed_projective)
swap_conll = conllu.parse(parsed_swap)
link2_conll = conllu.parse(parsed_link2)

# %%
disagr = []
sent = 0
for sentproj, sentswap, sentlink2 in zip(proj_conll, swap_conll, link2_conll):
    sent += 1
    for wordproj, wordswap, wordlink2 in zip(sentproj, sentswap, sentlink2):
        if (wordproj['deprel'] != wordswap['deprel']) or (wordproj['deprel'] != wordlink2['deprel']) or (wordswap['deprel'] != wordlink2['deprel']):
            disagr.append((sentproj, sentswap, sentlink2))
            break

# %%
for el in disagr:
    print(el[0].serialize())
    for sent in el:
        sent.to_tree().print_tree()
# Out:
# # sent_id = 1
# # text = Алгоритм, от имени учёного аль-Хорезми, - точный набор инструкций, описывающих порядок действий исполнителя для достижения результата решения задачи за конечное время.
# 1	Алгоритм	алгоритм	NOUN	_	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	10	nsubj	_	SpaceAfter=No
# 2	,	,	PUNCT	_	_	1	punct	_	_
# 3	от	от	ADP	_	_	4	case	_	_
# 4	имени	имя	NOUN	_	Animacy=Inan|Case=Dat|Gender=Neut|Number=Sing	1	nmod	_	_
# 5	учёного	учёный	ADJ	_	Case=Gen|Degree=Pos|Gender=Neut|Number=Sing	6	amod	_	_
# 6	аль-Хорезми	аль-Хорез	NOUN	_	Animacy=Inan|Case=Ins|Gender=Fem|Number=Plur	4	nmod	_	SpaceAfter=No
# 7	,	,	PUNCT	_	_	6	punct	_	_
# 8	-	-	PUNCT	_	_	1	punct	_	_
# 9	точный	точный	ADJ	_	Case=Nom|Degree=Pos|Gender=Masc|Number=Sing	10	amod	_	_
# 10	набор	набор	NOUN	_	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
# 11	инструкций	инструкция	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	10	nmod	_	SpaceAfter=No
# 12	,	,	PUNCT	_	_	13	punct	_	_
# 13	описывающих	описывать	VERB	_	Aspect=Imp|Case=Gen|Number=Plur|Tense=Pres|VerbForm=Part|Voice=Act	10	acl	_	SpacesAfter=\n
# 14	порядок	порядок	ADP	_	_	15	case	_	_
# 15	действий	действие	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur	13	obl	_	_
# 16	исполнителя	исполнитель	NOUN	_	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	15	nmod	_	_
# 17	для	для	ADP	_	_	18	case	_	_
# 18	достижения	достижение	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	16	nmod	_	_
# 19	результата	результат	NOUN	_	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	18	nmod	_	_
# 20	решения	решение	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	19	appos	_	_
# 21	задачи	задача	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	20	nmod	_	_
# 22	за	за	ADP	_	_	24	case	_	SpacesAfter=\n
# 23	конечное	конечный	ADJ	_	Case=Acc|Degree=Pos|Gender=Neut|Number=Sing	24	amod	_	_
# 24	время	время	NOUN	_	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	20	nmod	_	SpaceAfter=No
# 25	.	.	PUNCT	_	_	13	punct	_	_
#
#
# (deprel:root) form:набор lemma:набор upostag:NOUN [10]
#     (deprel:nsubj) form:Алгоритм lemma:алгоритм upostag:NOUN [1]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [2]
#         (deprel:nmod) form:имени lemma:имя upostag:NOUN [4]
#             (deprel:case) form:от lemma:от upostag:ADP [3]
#             (deprel:nmod) form:аль-Хорезми lemma:аль-Хорез upostag:NOUN [6]
#                 (deprel:amod) form:учёного lemma:учёный upostag:ADJ [5]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [7]
#         (deprel:punct) form:- lemma:- upostag:PUNCT [8]
#     (deprel:amod) form:точный lemma:точный upostag:ADJ [9]
#     (deprel:nmod) form:инструкций lemma:инструкция upostag:NOUN [11]
#     (deprel:acl) form:описывающих lemma:описывать upostag:VERB [13]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [12]
#         (deprel:obl) form:действий lemma:действие upostag:NOUN [15]
#             (deprel:case) form:порядок lemma:порядок upostag:ADP [14]
#             (deprel:nmod) form:исполнителя lemma:исполнитель upostag:NOUN [16]
#                 (deprel:nmod) form:достижения lemma:достижение upostag:NOUN [18]
#                     (deprel:case) form:для lemma:для upostag:ADP [17]
#                     (deprel:nmod) form:результата lemma:результат upostag:NOUN [19]
#                         (deprel:appos) form:решения lemma:решение upostag:NOUN [20]
#                             (deprel:nmod) form:задачи lemma:задача upostag:NOUN [21]
#                             (deprel:nmod) form:время lemma:время upostag:NOUN [24]
#                                 (deprel:case) form:за lemma:за upostag:ADP [22]
#                                 (deprel:amod) form:конечное lemma:конечный upostag:ADJ [23]
#         (deprel:punct) form:. lemma:. upostag:PUNCT [25]
# (deprel:root) form:Алгоритм lemma:алгоритм upostag:NOUN [1]
#     (deprel:conj) form:имени lemma:имя upostag:NOUN [4]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [2]
#         (deprel:case) form:от lemma:от upostag:ADP [3]
#         (deprel:nmod) form:аль-Хорезми lemma:аль-Хорез upostag:NOUN [6]
#             (deprel:amod) form:учёного lemma:учёный upostag:ADJ [5]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [7]
#         (deprel:punct) form:- lemma:- upostag:PUNCT [8]
#     (deprel:nsubj) form:набор lemma:набор upostag:NOUN [10]
#         (deprel:amod) form:точный lemma:точный upostag:ADJ [9]
#         (deprel:nmod) form:инструкций lemma:инструкция upostag:NOUN [11]
#         (deprel:acl) form:описывающих lemma:описывать upostag:VERB [13]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [12]
#             (deprel:obl) form:действий lemma:действие upostag:NOUN [15]
#                 (deprel:case) form:порядок lemma:порядок upostag:ADP [14]
#                 (deprel:nmod) form:исполнителя lemma:исполнитель upostag:NOUN [16]
#                     (deprel:nmod) form:достижения lemma:достижение upostag:NOUN [18]
#                         (deprel:case) form:для lemma:для upostag:ADP [17]
#                         (deprel:nmod) form:результата lemma:результат upostag:NOUN [19]
#                             (deprel:nmod) form:решения lemma:решение upostag:NOUN [20]
#                                 (deprel:nmod) form:задачи lemma:задача upostag:NOUN [21]
#             (deprel:obl) form:время lemma:время upostag:NOUN [24]
#                 (deprel:case) form:за lemma:за upostag:ADP [22]
#                 (deprel:amod) form:конечное lemma:конечный upostag:ADJ [23]
#             (deprel:punct) form:. lemma:. upostag:PUNCT [25]
# (deprel:root) form:Алгоритм lemma:алгоритм upostag:NOUN [1]
#     (deprel:conj) form:имени lemma:имя upostag:NOUN [4]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [2]
#         (deprel:case) form:от lemma:от upostag:ADP [3]
#         (deprel:nmod) form:аль-Хорезми lemma:аль-Хорез upostag:NOUN [6]
#             (deprel:amod) form:учёного lemma:учёный upostag:ADJ [5]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [7]
#         (deprel:punct) form:- lemma:- upostag:PUNCT [8]
#     (deprel:nsubj) form:набор lemma:набор upostag:NOUN [10]
#         (deprel:amod) form:точный lemma:точный upostag:ADJ [9]
#         (deprel:nmod) form:инструкций lemma:инструкцие upostag:NOUN [11]
#         (deprel:acl) form:описывающих lemma:описывать upostag:VERB [13]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [12]
#             (deprel:obl) form:действий lemma:действие upostag:NOUN [15]
#                 (deprel:case) form:порядок lemma:порядок upostag:ADP [14]
#                 (deprel:nmod) form:исполнителя lemma:исполнитель upostag:NOUN [16]
#             (deprel:obl) form:достижения lemma:достижение upostag:NOUN [18]
#                 (deprel:case) form:для lemma:для upostag:ADP [17]
#                 (deprel:nmod) form:результата lemma:результат upostag:NOUN [19]
#                     (deprel:nmod) form:решения lemma:решение upostag:NOUN [20]
#             (deprel:obl) form:задачи lemma:задача upostag:NOUN [21]
#             (deprel:obl) form:время lemma:время upostag:NOUN [24]
#                 (deprel:case) form:за lemma:за upostag:ADP [22]
#                 (deprel:amod) form:конечное lemma:конечный upostag:ADJ [23]
#             (deprel:punct) form:. lemma:. upostag:PUNCT [25]
# # sent_id = 2
# # text = В старой трактовке вместо слова "порядок" использовалось слово "последовательность", но по мере развития параллельности в работе компьютеров слово "последовательность" стали заменять более общим словом "порядок".
# 1	В	в	ADP	_	_	3	case	_	_
# 2	старой	старый	ADJ	_	Case=Dat|Degree=Pos|Gender=Fem|Number=Sing	3	amod	_	_
# 3	трактовке	трактовка	NOUN	_	Animacy=Inan|Case=Dat|Gender=Fem|Number=Sing	9	obl	_	_
# 4	вместо	вместо	ADP	_	_	5	case	_	_
# 5	слова	слово	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	3	nmod	_	_
# 6	"	"	PUNCT	_	_	7	punct	_	SpaceAfter=No
# 7	порядок	порядок	NOUN	_	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	5	appos	_	SpaceAfter=No
# 8	"	"	PUNCT	_	_	7	punct	_	_
# 9	использовалось	использоваться	VERB	_	Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
# 10	слово	слово	NOUN	_	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	9	obj	_	SpacesAfter=\n
# 11	"	"	PUNCT	_	_	12	punct	_	SpaceAfter=No
# 12	последовательность	последовательность	NOUN	_	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	10	obj	_	SpaceAfter=No
# 13	"	"	PUNCT	_	_	12	punct	_	SpaceAfter=No
# 14	,	,	PUNCT	_	_	27	punct	_	_
# 15	но	но	CCONJ	_	_	27	cc	_	_
# 16	по	по	ADP	_	_	18	case	_	_
# 17	мере	мера	NOUN	_	Animacy=Inan|Case=Dat|Gender=Fem|Number=Sing	16	fixed	_	_
# 18	развития	развитие	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	27	obl	_	_
# 19	параллельности	параллельность	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	18	nmod	_	_
# 20	в	в	ADP	_	_	21	case	_	_
# 21	работе	работа	NOUN	_	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	19	nmod	_	_
# 22	компьютеров	компьютер	NOUN	_	Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur	21	nmod	_	SpacesAfter=\n
# 23	слово	слово	ADV	_	Degree=Pos	27	advmod	_	_
# 24	"	"	PUNCT	_	_	23	punct	_	SpaceAfter=No
# 25	последовательность	последовательность	NOUN	_	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	24	obj	_	SpaceAfter=No
# 26	"	"	PUNCT	_	_	23	punct	_	_
# 27	стали	стать	VERB	_	Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act	9	conj	_	_
# 28	заменять	заменять	VERB	_	Aspect=Imp|VerbForm=Inf|Voice=Act	27	xcomp	_	_
# 29	более	более	ADV	_	Degree=Cmp	30	advmod	_	_
# 30	общим	обть	VERB	_	Aspect=Imp|Case=Ins|Gender=Masc|Number=Sing|Tense=Pres|VerbForm=Part|Voice=Act	31	acl	_	_
# 31	словом	слов	NOUN	_	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	28	obl	_	_
# 32	"	"	PUNCT	_	_	33	punct	_	SpaceAfter=No
# 33	порядок	порядок	NOUN	_	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	31	appos	_	SpaceAfter=No
# 34	"	"	PUNCT	_	_	33	punct	_	SpaceAfter=No
# 35	.	.	PUNCT	_	_	33	punct	_	_
#
#
# (deprel:root) form:использовалось lemma:использоваться upostag:VERB [9]
#     (deprel:obl) form:трактовке lemma:трактовка upostag:NOUN [3]
#         (deprel:case) form:В lemma:в upostag:ADP [1]
#         (deprel:amod) form:старой lemma:старый upostag:ADJ [2]
#         (deprel:nmod) form:слова lemma:слово upostag:NOUN [5]
#             (deprel:case) form:вместо lemma:вместо upostag:ADP [4]
#             (deprel:appos) form:порядок lemma:порядок upostag:NOUN [7]
#                 (deprel:punct) form:" lemma:" upostag:PUNCT [6]
#                 (deprel:punct) form:" lemma:" upostag:PUNCT [8]
#     (deprel:obj) form:слово lemma:слово upostag:NOUN [10]
#         (deprel:obj) form:последовательность lemma:последовательность upostag:NOUN [12]
#             (deprel:punct) form:" lemma:" upostag:PUNCT [11]
#             (deprel:punct) form:" lemma:" upostag:PUNCT [13]
#     (deprel:conj) form:стали lemma:стать upostag:VERB [27]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [14]
#         (deprel:cc) form:но lemma:но upostag:CCONJ [15]
#         (deprel:obl) form:развития lemma:развитие upostag:NOUN [18]
#             (deprel:case) form:по lemma:по upostag:ADP [16]
#                 (deprel:fixed) form:мере lemma:мера upostag:NOUN [17]
#             (deprel:nmod) form:параллельности lemma:параллельность upostag:NOUN [19]
#                 (deprel:nmod) form:работе lemma:работа upostag:NOUN [21]
#                     (deprel:case) form:в lemma:в upostag:ADP [20]
#                     (deprel:nmod) form:компьютеров lemma:компьютер upostag:NOUN [22]
#         (deprel:advmod) form:слово lemma:слово upostag:ADV [23]
#             (deprel:punct) form:" lemma:" upostag:PUNCT [24]
#                 (deprel:obj) form:последовательность lemma:последовательность upostag:NOUN [25]
#             (deprel:punct) form:" lemma:" upostag:PUNCT [26]
#         (deprel:xcomp) form:заменять lemma:заменять upostag:VERB [28]
#             (deprel:obl) form:словом lemma:слов upostag:NOUN [31]
#                 (deprel:acl) form:общим lemma:обть upostag:VERB [30]
#                     (deprel:advmod) form:более lemma:более upostag:ADV [29]
#                 (deprel:appos) form:порядок lemma:порядок upostag:NOUN [33]
#                     (deprel:punct) form:" lemma:" upostag:PUNCT [32]
#                     (deprel:punct) form:" lemma:" upostag:PUNCT [34]
#                     (deprel:punct) form:. lemma:. upostag:PUNCT [35]
# (deprel:root) form:использовалось lemma:использоваться upostag:VERB [9]
#     (deprel:obl) form:трактовке lemma:трактовка upostag:NOUN [3]
#         (deprel:case) form:В lemma:в upostag:ADP [1]
#         (deprel:amod) form:старой lemma:старый upostag:ADJ [2]
#         (deprel:nmod) form:слова lemma:слово upostag:NOUN [5]
#             (deprel:case) form:вместо lemma:вместо upostag:ADP [4]
#             (deprel:appos) form:порядок lemma:порядок upostag:NOUN [7]
#                 (deprel:punct) form:" lemma:" upostag:PUNCT [6]
#                 (deprel:punct) form:" lemma:" upostag:PUNCT [8]
#     (deprel:obl) form:последовательность lemma:последовательность upostag:VERB [12]
#         (deprel:advmod) form:слово lemma:слово upostag:ADV [10]
#         (deprel:punct) form:" lemma:" upostag:PUNCT [11]
#         (deprel:punct) form:" lemma:" upostag:PUNCT [13]
#         (deprel:conj) form:стали lemma:стать upostag:VERB [27]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [14]
#             (deprel:cc) form:но lemma:но upostag:CCONJ [15]
#             (deprel:obl) form:мере lemma:мера upostag:NOUN [17]
#                 (deprel:case) form:по lemma:по upostag:ADP [16]
#                 (deprel:nmod) form:развития lemma:развитие upostag:NOUN [18]
#                     (deprel:nmod) form:параллельности lemma:параллельность upostag:NOUN [19]
#                 (deprel:nmod) form:работе lemma:работ upostag:NOUN [21]
#                     (deprel:case) form:в lemma:в upostag:ADP [20]
#                     (deprel:nmod) form:компьютеров lemma:компьютер upostag:NOUN [22]
#             (deprel:advmod) form:слово lemma:слово upostag:ADV [23]
#             (deprel:obj) form:последовательность lemma:последовательность upostag:NOUN [25]
#                 (deprel:punct) form:" lemma:" upostag:PUNCT [24]
#                 (deprel:punct) form:" lemma:" upostag:PUNCT [26]
#             (deprel:xcomp) form:заменять lemma:заменять upostag:VERB [28]
#                 (deprel:obl) form:словом lemma:слов upostag:NOUN [31]
#                     (deprel:amod) form:общим lemma:обть upostag:VERB [30]
#                         (deprel:advmod) form:более lemma:более upostag:ADV [29]
#                     (deprel:appos) form:порядок lemma:порядок upostag:NOUN [33]
#                         (deprel:punct) form:" lemma:" upostag:PUNCT [32]
#                         (deprel:punct) form:" lemma:" upostag:PUNCT [34]
#                         (deprel:punct) form:. lemma:. upostag:PUNCT [35]
# (deprel:root) form:использовалось lemma:использоваться upostag:VERB [9]
#     (deprel:obl) form:трактовке lemma:трактовка upostag:NOUN [3]
#         (deprel:case) form:В lemma:в upostag:ADP [1]
#         (deprel:amod) form:старой lemma:старый upostag:ADJ [2]
#     (deprel:obl) form:слова lemma:слово upostag:NOUN [5]
#         (deprel:case) form:вместо lemma:вместо upostag:ADP [4]
#         (deprel:appos) form:порядок lemma:порядок upostag:NOUN [7]
#             (deprel:punct) form:" lemma:" upostag:PUNCT [6]
#             (deprel:punct) form:" lemma:" upostag:PUNCT [8]
#     (deprel:obj) form:слово lemma:слово upostag:NOUN [10]
#         (deprel:appos) form:последовательность lemma:последовательность upostag:NOUN [12]
#             (deprel:punct) form:" lemma:" upostag:PUNCT [11]
#             (deprel:punct) form:" lemma:" upostag:PUNCT [13]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [14]
#     (deprel:conj) form:стали lemma:стать upostag:VERB [27]
#         (deprel:cc) form:но lemma:но upostag:CCONJ [15]
#         (deprel:obl) form:мере lemma:мера upostag:NOUN [17]
#             (deprel:case) form:по lemma:по upostag:ADP [16]
#             (deprel:nmod) form:развития lemma:развитие upostag:NOUN [18]
#                 (deprel:nmod) form:параллельности lemma:параллельность upostag:NOUN [19]
#             (deprel:nmod) form:работе lemma:работ upostag:NOUN [21]
#                 (deprel:case) form:в lemma:в upostag:ADP [20]
#                 (deprel:nmod) form:компьютеров lemma:компьютер upostag:NOUN [22]
#                 (deprel:conj) form:последовательность lemma:последовательность upostag:NOUN [25]
#                     (deprel:det) form:слово lemma:слово upostag:ADV [23]
#                     (deprel:punct) form:" lemma:" upostag:PUNCT [24]
#                     (deprel:punct) form:" lemma:" upostag:PUNCT [26]
#         (deprel:xcomp) form:заменять lemma:заменять upostag:VERB [28]
#             (deprel:obl) form:словом lemma:слов upostag:NOUN [31]
#                 (deprel:acl) form:общим lemma:обть upostag:VERB [30]
#                     (deprel:advmod) form:более lemma:более upostag:ADV [29]
#                 (deprel:appos) form:порядок lemma:порядок upostag:NOUN [33]
#                     (deprel:punct) form:" lemma:" upostag:PUNCT [32]
#                     (deprel:punct) form:" lemma:" upostag:PUNCT [34]
#                     (deprel:punct) form:. lemma:. upostag:PUNCT [35]
# # sent_id = 3
# # text = Это связано с тем, что работа каких-то инструкций алгоритма может быть зависима от других инструкций или результатов их работы.
# 1	Это	это	PRON	_	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	2	nsubj:pass	_	SpacesAfter=\n
# 2	связано	связать	VERB	_	Aspect=Perf|Gender=Neut|Number=Sing|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass	0	root	_	_
# 3	с	с	ADP	_	_	4	case	_	_
# 4	тем	то	PRON	_	Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing	2	obl	_	SpaceAfter=No
# 5	,	,	PUNCT	_	_	11	punct	_	_
# 6	что	что	SCONJ	_	_	11	mark	_	_
# 7	работа	торабот	DET	_	Case=Nom|Gender=Fem|Number=Sing	9	det	_	_
# 8	каких-то	какой-то	DET	_	Case=Gen|Number=Plur	9	det	_	_
# 9	инструкций	инструкция	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	11	nsubj:pass	_	_
# 10	алгоритма	алгоритм	NOUN	_	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	9	nmod	_	_
# 11	может	мочь	VERB	_	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	2	ccomp	_	_
# 12	быть	быть	AUX	_	Aspect=Imp|VerbForm=Inf|Voice=Act	13	cop	_	_
# 13	зависима	зависить	VERB	_	Aspect=Imp|Gender=Fem|Number=Sing|Tense=Pres|Variant=Short|VerbForm=Part|Voice=Pass	11	xcomp	_	_
# 14	от	от	ADP	_	_	16	case	_	SpacesAfter=\n
# 15	других	другой	ADJ	_	Case=Gen|Degree=Pos|Number=Plur	16	amod	_	_
# 16	инструкций	инструкция	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	13	obl	_	_
# 17	или	или	CCONJ	_	_	18	cc	_	_
# 18	результатов	результат	NOUN	_	Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur	16	conj	_	_
# 19	их	их	DET	_	_	20	det	_	_
# 20	работы	работа	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	18	nmod	_	SpaceAfter=No
# 21	.	.	PUNCT	_	_	11	punct	_	_
#
#
# (deprel:root) form:связано lemma:связать upostag:VERB [2]
#     (deprel:nsubj:pass) form:Это lemma:это upostag:PRON [1]
#     (deprel:obl) form:тем lemma:то upostag:PRON [4]
#         (deprel:case) form:с lemma:с upostag:ADP [3]
#     (deprel:ccomp) form:может lemma:мочь upostag:VERB [11]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [5]
#         (deprel:mark) form:что lemma:что upostag:SCONJ [6]
#         (deprel:nsubj:pass) form:инструкций lemma:инструкция upostag:NOUN [9]
#             (deprel:det) form:работа lemma:торабот upostag:DET [7]
#             (deprel:det) form:каких-то lemma:какой-то upostag:DET [8]
#             (deprel:nmod) form:алгоритма lemma:алгоритм upostag:NOUN [10]
#         (deprel:xcomp) form:зависима lemma:зависить upostag:VERB [13]
#             (deprel:cop) form:быть lemma:быть upostag:AUX [12]
#             (deprel:obl) form:инструкций lemma:инструкция upostag:NOUN [16]
#                 (deprel:case) form:от lemma:от upostag:ADP [14]
#                 (deprel:amod) form:других lemma:другой upostag:ADJ [15]
#                 (deprel:conj) form:результатов lemma:результат upostag:NOUN [18]
#                     (deprel:cc) form:или lemma:или upostag:CCONJ [17]
#                     (deprel:nmod) form:работы lemma:работа upostag:NOUN [20]
#                         (deprel:det) form:их lemma:их upostag:DET [19]
#         (deprel:punct) form:. lemma:. upostag:PUNCT [21]
# (deprel:root) form:связано lemma:связать upostag:VERB [2]
#     (deprel:nsubj:pass) form:Это lemma:это upostag:PRON [1]
#     (deprel:obl) form:тем lemma:то upostag:PRON [4]
#         (deprel:case) form:с lemma:с upostag:ADP [3]
#         (deprel:acl) form:может lemma:мочь upostag:VERB [11]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [5]
#             (deprel:mark) form:что lemma:что upostag:SCONJ [6]
#             (deprel:iobj) form:инструкций lemma:инструкция upostag:NOUN [9]
#                 (deprel:det) form:работа lemma:торабот upostag:DET [7]
#                 (deprel:det) form:каких-то lemma:какой-то upostag:DET [8]
#                 (deprel:nmod) form:алгоритма lemma:алгоритм upostag:NOUN [10]
#             (deprel:xcomp) form:зависима lemma:зависимый upostag:ADJ [13]
#                 (deprel:cop) form:быть lemma:быть upostag:AUX [12]
#                 (deprel:obl) form:инструкций lemma:инструкция upostag:NOUN [16]
#                     (deprel:case) form:от lemma:от upostag:ADP [14]
#                     (deprel:amod) form:других lemma:другой upostag:ADJ [15]
#                     (deprel:conj) form:результатов lemma:результат upostag:NOUN [18]
#                         (deprel:cc) form:или lemma:или upostag:CCONJ [17]
#                         (deprel:nmod) form:работы lemma:работа upostag:NOUN [20]
#                             (deprel:det) form:их lemma:их upostag:DET [19]
#             (deprel:punct) form:. lemma:. upostag:PUNCT [21]
# (deprel:root) form:связано lemma:связать upostag:VERB [2]
#     (deprel:nsubj:pass) form:Это lemma:это upostag:PRON [1]
#     (deprel:obl) form:тем lemma:то upostag:PRON [4]
#         (deprel:case) form:с lemma:с upostag:ADP [3]
#         (deprel:acl) form:может lemma:мочь upostag:VERB [11]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [5]
#             (deprel:mark) form:что lemma:что upostag:SCONJ [6]
#             (deprel:nsubj) form:работа lemma:работ upostag:NOUN [7]
#                 (deprel:nmod) form:инструкций lemma:инструкция upostag:NOUN [9]
#                     (deprel:det) form:каких-то lemma:какой-то upostag:DET [8]
#                     (deprel:nmod) form:алгоритма lemma:алгоритм upostag:NOUN [10]
#             (deprel:xcomp) form:зависима lemma:зависить upostag:VERB [13]
#                 (deprel:aux:pass) form:быть lemma:быть upostag:AUX [12]
#                 (deprel:obl) form:инструкций lemma:инструкция upostag:NOUN [16]
#                     (deprel:case) form:от lemma:от upostag:ADP [14]
#                     (deprel:amod) form:других lemma:другой upostag:ADJ [15]
#                     (deprel:conj) form:результатов lemma:результат upostag:NOUN [18]
#                         (deprel:cc) form:или lemma:или upostag:CCONJ [17]
#                         (deprel:nmod) form:работы lemma:работа upostag:NOUN [20]
#                             (deprel:det) form:их lemma:их upostag:DET [19]
#             (deprel:punct) form:. lemma:. upostag:PUNCT [21]
# # sent_id = 4
# # text = Таким образом, некоторые инструкции должны выполняться строго после завершения работы инструкций, от которых они зависят.
# 1	Таким	такой	DET	_	Case=Ins|Gender=Masc|Number=Sing	2	det	_	_
# 2	образом	образ	NOUN	_	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	6	parataxis	_	SpaceAfter=No
# 3	,	,	PUNCT	_	_	2	punct	_	_
# 4	некоторые	некоторый	DET	_	Case=Nom|Number=Plur	5	det	_	_
# 5	инструкции	инструкция	NOUN	_	Animacy=Inan|Case=Nom|Gender=Fem|Number=Plur	6	nsubj	_	SpacesAfter=\n
# 6	должны	должен	ADJ	_	Degree=Pos|Number=Plur|Variant=Short	0	root	_	_
# 7	выполняться	выполняться	VERB	_	Aspect=Imp|VerbForm=Inf|Voice=Mid	6	xcomp	_	_
# 8	строго	строго	ADV	_	Degree=Pos	10	obl	_	_
# 9	после	после	ADP	_	_	10	case	_	_
# 10	завершения	завершение	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	7	obl	_	_
# 11	работы	работа	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	10	nmod	_	_
# 12	инструкций	инструкция	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	11	nmod	_	SpaceAfter=No
# 13	,	,	PUNCT	_	_	17	punct	_	_
# 14	от	от	ADP	_	_	15	case	_	_
# 15	которых	который	PRON	_	Case=Gen	17	obl	_	_
# 16	они	они	PRON	_	Case=Nom|Number=Plur|Person=3	17	nsubj	_	SpacesAfter=\n
# 17	зависят	зависеть	VERB	_	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	12	acl:relcl	_	SpaceAfter=No
# 18	.	.	PUNCT	_	_	17	punct	_	_
#
#
# (deprel:root) form:должны lemma:должен upostag:ADJ [6]
#     (deprel:parataxis) form:образом lemma:образ upostag:NOUN [2]
#         (deprel:det) form:Таким lemma:такой upostag:DET [1]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [3]
#     (deprel:nsubj) form:инструкции lemma:инструкция upostag:NOUN [5]
#         (deprel:det) form:некоторые lemma:некоторый upostag:DET [4]
#     (deprel:xcomp) form:выполняться lemma:выполняться upostag:VERB [7]
#         (deprel:obl) form:завершения lemma:завершение upostag:NOUN [10]
#             (deprel:obl) form:строго lemma:строго upostag:ADV [8]
#             (deprel:case) form:после lemma:после upostag:ADP [9]
#             (deprel:nmod) form:работы lemma:работа upostag:NOUN [11]
#                 (deprel:nmod) form:инструкций lemma:инструкция upostag:NOUN [12]
#                     (deprel:acl:relcl) form:зависят lemma:зависеть upostag:VERB [17]
#                         (deprel:punct) form:, lemma:, upostag:PUNCT [13]
#                         (deprel:obl) form:которых lemma:который upostag:PRON [15]
#                             (deprel:case) form:от lemma:от upostag:ADP [14]
#                         (deprel:nsubj) form:они lemma:они upostag:PRON [16]
#                         (deprel:punct) form:. lemma:. upostag:PUNCT [18]
# (deprel:root) form:должны lemma:должен upostag:ADJ [6]
#     (deprel:parataxis) form:образом lemma:образ upostag:NOUN [2]
#         (deprel:det) form:Таким lemma:такой upostag:DET [1]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [3]
#     (deprel:nsubj) form:инструкции lemma:инструкция upostag:NOUN [5]
#         (deprel:det) form:некоторые lemma:некоторый upostag:DET [4]
#     (deprel:xcomp) form:выполняться lemma:выполняться upostag:VERB [7]
#         (deprel:obl) form:строго lemma:строго upostag:ADV [8]
#             (deprel:obl) form:завершения lemma:завершение upostag:NOUN [10]
#                 (deprel:case) form:после lemma:после upostag:ADP [9]
#                 (deprel:nmod) form:работы lemma:работа upostag:NOUN [11]
#                     (deprel:nmod) form:инструкций lemma:инструкция upostag:NOUN [12]
#                         (deprel:acl:relcl) form:зависят lemma:зависеть upostag:VERB [17]
#                             (deprel:punct) form:, lemma:, upostag:PUNCT [13]
#                             (deprel:obl) form:которых lemma:который upostag:PRON [15]
#                                 (deprel:case) form:от lemma:от upostag:ADP [14]
#                             (deprel:nsubj) form:они lemma:они upostag:PRON [16]
#                             (deprel:punct) form:. lemma:. upostag:PUNCT [18]
# (deprel:root) form:должны lemma:должен upostag:ADJ [6]
#     (deprel:parataxis) form:образом lemma:образ upostag:NOUN [2]
#         (deprel:det) form:Таким lemma:такой upostag:ADJ [1]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [3]
#     (deprel:nsubj) form:инструкции lemma:инструкция upostag:NOUN [5]
#         (deprel:det) form:некоторые lemma:некоторый upostag:DET [4]
#     (deprel:xcomp) form:выполняться lemma:выполняться upostag:VERB [7]
#         (deprel:obl) form:завершения lemma:завершение upostag:NOUN [10]
#             (deprel:obl) form:строго lemma:строго upostag:ADV [8]
#             (deprel:case) form:после lemma:после upostag:ADP [9]
#             (deprel:nmod) form:работы lemma:работа upostag:NOUN [11]
#                 (deprel:nmod) form:инструкций lemma:инструкция upostag:NOUN [12]
#         (deprel:conj) form:зависят lemma:зависеть upostag:VERB [17]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [13]
#             (deprel:obl) form:которых lemma:который upostag:PRON [15]
#                 (deprel:case) form:от lemma:от upostag:ADP [14]
#             (deprel:nsubj) form:они lemma:они upostag:PRON [16]
#             (deprel:punct) form:. lemma:. upostag:PUNCT [18]
# # sent_id = 5
# # text = Независимые инструкции или инструкции, ставшие независимыми из-за завершения работы инструкций, от которых они зависят, могут выполняться в произвольном порядке, параллельно или одновременно, если это позволяют используемые процессор и операционная система.
# 1	Независимые	Независимый	ADJ	_	Case=Nom|Degree=Pos|Number=Plur	2	amod	_	_
# 2	инструкции	инструкция	NOUN	_	Animacy=Inan|Case=Nom|Gender=Fem|Number=Plur	18	nsubj	_	_
# 3	или	или	CCONJ	_	_	4	cc	_	_
# 4	инструкции	инструкция	NOUN	_	Animacy=Inan|Case=Nom|Gender=Fem|Number=Plur	2	conj	_	SpaceAfter=No
# 5	,	,	PUNCT	_	_	6	punct	_	_
# 6	ставшие	ставшие	NOUN	_	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	2	conj	_	_
# 7	независимыми	независимый	ADJ	_	Case=Ins|Degree=Pos|Number=Plur	9	amod	_	_
# 8	из-за	из-за	ADP	_	_	9	case	_	SpacesAfter=\n
# 9	завершения	завершение	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	6	nmod	_	_
# 10	работы	работа	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	9	nmod	_	_
# 11	инструкций	инструкция	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	10	nmod	_	SpaceAfter=No
# 12	,	,	PUNCT	_	_	16	punct	_	_
# 13	от	от	ADP	_	_	14	case	_	_
# 14	которых	который	PRON	_	Case=Gen	16	obl	_	_
# 15	они	они	PRON	_	Case=Nom|Number=Plur|Person=3	16	nsubj	_	_
# 16	зависят	зависеть	VERB	_	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	11	acl:relcl	_	SpaceAfter=No
# 17	,	,	PUNCT	_	_	16	punct	_	_
# 18	могут	мочь	VERB	_	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	0	root	_	_
# 19	выполняться	выполняться	VERB	_	Aspect=Imp|VerbForm=Inf|Voice=Mid	18	xcomp	_	_
# 20	в	в	ADP	_	_	22	case	_	SpacesAfter=\n
# 21	произвольном	произвольный	ADJ	_	Case=Loc|Degree=Pos|Gender=Masc|Number=Sing	22	amod	_	_
# 22	порядке	порядок	NOUN	_	Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing	19	obl	_	SpaceAfter=No
# 23	,	,	PUNCT	_	_	24	punct	_	_
# 24	параллельно	параллельно	ADV	_	Degree=Pos	18	conj	_	_
# 25	или	или	CCONJ	_	_	26	cc	_	_
# 26	одновременно	одновременно	ADV	_	Degree=Pos	24	conj	_	SpaceAfter=No
# 27	,	,	PUNCT	_	_	30	punct	_	_
# 28	если	если	SCONJ	_	_	30	mark	_	_
# 29	это	это	PRON	_	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	30	nsubj	_	_
# 30	позволяют	позволять	VERB	_	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	26	advcl	_	SpacesAfter=\n
# 31	используемые	используемый	ADJ	_	Animacy=Inan|Case=Acc|Degree=Pos|Number=Plur	32	amod	_	_
# 32	процессор	процессор	NOUN	_	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	30	obj	_	_
# 33	и	и	CCONJ	_	_	35	cc	_	_
# 34	операционная	операционный	ADJ	_	Case=Nom|Degree=Pos|Gender=Fem|Number=Sing	35	amod	_	_
# 35	система	система	NOUN	_	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	32	conj	_	SpaceAfter=No
# 36	.	.	PUNCT	_	_	30	punct	_	_
#
#
# (deprel:root) form:могут lemma:мочь upostag:VERB [18]
#     (deprel:nsubj) form:инструкции lemma:инструкция upostag:NOUN [2]
#         (deprel:amod) form:Независимые lemma:Независимый upostag:ADJ [1]
#         (deprel:conj) form:инструкции lemma:инструкция upostag:NOUN [4]
#             (deprel:cc) form:или lemma:или upostag:CCONJ [3]
#         (deprel:conj) form:ставшие lemma:ставшие upostag:NOUN [6]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [5]
#             (deprel:nmod) form:завершения lemma:завершение upostag:NOUN [9]
#                 (deprel:amod) form:независимыми lemma:независимый upostag:ADJ [7]
#                 (deprel:case) form:из-за lemma:из-за upostag:ADP [8]
#                 (deprel:nmod) form:работы lemma:работа upostag:NOUN [10]
#                     (deprel:nmod) form:инструкций lemma:инструкция upostag:NOUN [11]
#                         (deprel:acl:relcl) form:зависят lemma:зависеть upostag:VERB [16]
#                             (deprel:punct) form:, lemma:, upostag:PUNCT [12]
#                             (deprel:obl) form:которых lemma:который upostag:PRON [14]
#                                 (deprel:case) form:от lemma:от upostag:ADP [13]
#                             (deprel:nsubj) form:они lemma:они upostag:PRON [15]
#                             (deprel:punct) form:, lemma:, upostag:PUNCT [17]
#     (deprel:xcomp) form:выполняться lemma:выполняться upostag:VERB [19]
#         (deprel:obl) form:порядке lemma:порядок upostag:NOUN [22]
#             (deprel:case) form:в lemma:в upostag:ADP [20]
#             (deprel:amod) form:произвольном lemma:произвольный upostag:ADJ [21]
#     (deprel:conj) form:параллельно lemma:параллельно upostag:ADV [24]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [23]
#         (deprel:conj) form:одновременно lemma:одновременно upostag:ADV [26]
#             (deprel:cc) form:или lemma:или upostag:CCONJ [25]
#             (deprel:advcl) form:позволяют lemma:позволять upostag:VERB [30]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [27]
#                 (deprel:mark) form:если lemma:если upostag:SCONJ [28]
#                 (deprel:nsubj) form:это lemma:это upostag:PRON [29]
#                 (deprel:obj) form:процессор lemma:процессор upostag:NOUN [32]
#                     (deprel:amod) form:используемые lemma:используемый upostag:ADJ [31]
#                     (deprel:conj) form:система lemma:система upostag:NOUN [35]
#                         (deprel:cc) form:и lemma:и upostag:CCONJ [33]
#                         (deprel:amod) form:операционная lemma:операционный upostag:ADJ [34]
#                 (deprel:punct) form:. lemma:. upostag:PUNCT [36]
# (deprel:root) form:могут lemma:мочь upostag:VERB [18]
#     (deprel:nsubj) form:инструкции lemma:инструкция upostag:NOUN [2]
#         (deprel:amod) form:Независимые lemma:Независимый upostag:ADJ [1]
#         (deprel:conj) form:инструкции lemma:инструкция upostag:NOUN [4]
#             (deprel:cc) form:или lemma:или upostag:CCONJ [3]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [5]
#     (deprel:nsubj) form:ставшие lemma:ставшие upostag:NOUN [6]
#         (deprel:nmod) form:завершения lemma:завершение upostag:NOUN [9]
#             (deprel:amod) form:независимыми lemma:независимый upostag:ADJ [7]
#             (deprel:case) form:из-за lemma:из-за upostag:ADP [8]
#             (deprel:nmod) form:работы lemma:работа upostag:NOUN [10]
#                 (deprel:nmod) form:инструкций lemma:инструкция upostag:NOUN [11]
#                     (deprel:acl:relcl) form:зависят lemma:зависеть upostag:VERB [16]
#                         (deprel:punct) form:, lemma:, upostag:PUNCT [12]
#                         (deprel:obl) form:которых lemma:который upostag:PRON [14]
#                             (deprel:case) form:от lemma:от upostag:ADP [13]
#                         (deprel:nsubj) form:они lemma:они upostag:PRON [15]
#                         (deprel:punct) form:, lemma:, upostag:PUNCT [17]
#     (deprel:xcomp) form:выполняться lemma:выполняться upostag:VERB [19]
#         (deprel:obl) form:порядке lemma:порядок upostag:NOUN [22]
#             (deprel:case) form:в lemma:в upostag:ADP [20]
#             (deprel:amod) form:произвольном lemma:произвольный upostag:ADJ [21]
#         (deprel:conj) form:параллельно lemma:параллельно upostag:ADV [24]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [23]
#     (deprel:conj) form:одновременно lemma:одновременно upostag:ADV [26]
#         (deprel:cc) form:или lemma:или upostag:CCONJ [25]
#         (deprel:advcl) form:позволяют lemma:позволять upostag:VERB [30]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [27]
#             (deprel:mark) form:если lemma:если upostag:SCONJ [28]
#             (deprel:nsubj) form:это lemma:это upostag:PRON [29]
#             (deprel:obj) form:процессор lemma:процессор upostag:NOUN [32]
#                 (deprel:amod) form:используемые lemma:используемый upostag:ADJ [31]
#                 (deprel:conj) form:система lemma:система upostag:NOUN [35]
#                     (deprel:cc) form:и lemma:и upostag:CCONJ [33]
#                     (deprel:amod) form:операционная lemma:операционный upostag:ADJ [34]
#             (deprel:punct) form:. lemma:. upostag:PUNCT [36]
# (deprel:root) form:могут lemma:мочь upostag:VERB [18]
#     (deprel:nsubj) form:инструкции lemma:инструкция upostag:NOUN [2]
#         (deprel:amod) form:Независимые lemma:Независимый upostag:ADJ [1]
#         (deprel:conj) form:инструкции lemma:инструкция upostag:NOUN [4]
#             (deprel:cc) form:или lemma:или upostag:CCONJ [3]
#         (deprel:conj) form:ставшие lemma:ставшие upostag:NOUN [6]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [5]
#             (deprel:nmod) form:завершения lemma:завершение upostag:NOUN [9]
#                 (deprel:amod) form:независимыми lemma:независимый upostag:ADJ [7]
#                 (deprel:case) form:из-за lemma:из-за upostag:ADP [8]
#                 (deprel:nmod) form:работы lemma:работа upostag:NOUN [10]
#                     (deprel:nmod) form:инструкций lemma:инструкция upostag:NOUN [11]
#                         (deprel:acl:relcl) form:зависят lemma:зависеть upostag:VERB [16]
#                             (deprel:punct) form:, lemma:, upostag:PUNCT [12]
#                             (deprel:obl) form:которых lemma:который upostag:PRON [14]
#                                 (deprel:case) form:от lemma:от upostag:ADP [13]
#                             (deprel:nsubj) form:они lemma:они upostag:PRON [15]
#                             (deprel:punct) form:, lemma:, upostag:PUNCT [17]
#     (deprel:xcomp) form:выполняться lemma:выполняться upostag:VERB [19]
#         (deprel:obl) form:порядке lemma:порядок upostag:NOUN [22]
#             (deprel:case) form:в lemma:в upostag:ADP [20]
#             (deprel:amod) form:произвольном lemma:произвольный upostag:ADJ [21]
#     (deprel:parataxis) form:позволяют lemma:позволять upostag:VERB [30]
#         (deprel:advmod) form:параллельно lemma:параллельно upostag:ADV [24]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [23]
#             (deprel:conj) form:одновременно lemma:одновременно upostag:ADV [26]
#                 (deprel:cc) form:или lemma:или upostag:CCONJ [25]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [27]
#         (deprel:mark) form:если lemma:если upostag:SCONJ [28]
#         (deprel:nsubj) form:это lemma:это upostag:PRON [29]
#         (deprel:nsubj) form:процессор lemma:процессор upostag:NOUN [32]
#             (deprel:amod) form:используемые lemma:используемый upostag:ADJ [31]
#             (deprel:conj) form:система lemma:система upostag:NOUN [35]
#                 (deprel:cc) form:и lemma:и upostag:CCONJ [33]
#                 (deprel:amod) form:операционная lemma:операционный upostag:ADJ [34]
#         (deprel:punct) form:. lemma:. upostag:PUNCT [36]
# # sent_id = 6
# # text = Ранее часто писали "алгорифм", сейчас такое написание используется редко, но, тем не менее, имеет место (например, Нормальный алгорифм Маркова).
# 1	Ранее	раний	ADJ	_	Case=Nom|Degree=Pos|Gender=Neut|Number=Sing	2	amod	_	_
# 2	часто	часто	NOUN	_	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	3	nsubj	_	_
# 3	писали	писать	VERB	_	Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act	0	root	_	_
# 4	"	"	PUNCT	_	_	5	punct	_	SpaceAfter=No
# 5	алгорифм	алгорифй	ADJ	_	Case=Ins|Degree=Pos|Gender=Masc|Number=Sing	3	obl	_	SpaceAfter=No
# 6	"	"	PUNCT	_	_	5	punct	_	SpaceAfter=No
# 7	,	,	PUNCT	_	_	5	punct	_	SpacesAfter=\n
# 8	сейчас	сейчас	ADV	_	Degree=Pos	3	advmod	_	_
# 9	такое	такой	DET	_	Case=Nom|Gender=Neut|Number=Sing	10	det	_	_
# 10	написание	написание	NOUN	_	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	11	nsubj:pass	_	_
# 11	используется	использовать	VERB	_	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Pass	3	parataxis	_	_
# 12	редко	редко	ADV	_	Degree=Pos	11	advmod	_	SpaceAfter=No
# 13	,	,	PUNCT	_	_	14	punct	_	_
# 14	но	но	CCONJ	_	_	20	cc	_	SpaceAfter=No
# 15	,	,	PUNCT	_	_	14	punct	_	_
# 16	тем	то	PRON	_	Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing	20	parataxis	_	_
# 17	не	не	PART	_	_	18	advmod	_	_
# 18	менее	мено	ADV	_	Degree=Cmp	16	fixed	_	SpaceAfter=No
# 19	,	,	PUNCT	_	_	16	punct	_	_
# 20	имеет	иметь	VERB	_	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	11	conj	_	_
# 21	место	место	NOUN	_	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	20	nsubj	_	SpacesAfter=\n
# 22	(	(	PUNCT	_	_	27	punct	_	SpaceAfter=No
# 23	например	например	ADV	_	Degree=Pos	27	parataxis	_	SpaceAfter=No
# 24	,	,	PUNCT	_	_	23	punct	_	_
# 25	Нормальный	нормальный	ADJ	_	Case=Nom|Degree=Pos|Gender=Masc|Number=Sing	27	amod	_	_
# 26	алгорифм	алгорифй	ADJ	_	Case=Ins|Degree=Pos|Gender=Masc|Number=Sing	27	amod	_	_
# 27	Маркова	Марков	PROPN	_	Animacy=Anim|Case=Acc|Gender=Masc|Number=Sing	21	appos	_	SpaceAfter=No
# 28	)	)	PUNCT	_	_	27	punct	_	SpaceAfter=No
# 29	.	.	PUNCT	_	_	27	punct	_	_
#
#
# (deprel:root) form:писали lemma:писать upostag:VERB [3]
#     (deprel:nsubj) form:часто lemma:часто upostag:NOUN [2]
#         (deprel:amod) form:Ранее lemma:раний upostag:ADJ [1]
#     (deprel:obl) form:алгорифм lemma:алгорифй upostag:ADJ [5]
#         (deprel:punct) form:" lemma:" upostag:PUNCT [4]
#         (deprel:punct) form:" lemma:" upostag:PUNCT [6]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [7]
#     (deprel:advmod) form:сейчас lemma:сейчас upostag:ADV [8]
#     (deprel:parataxis) form:используется lemma:использовать upostag:VERB [11]
#         (deprel:nsubj:pass) form:написание lemma:написание upostag:NOUN [10]
#             (deprel:det) form:такое lemma:такой upostag:DET [9]
#         (deprel:advmod) form:редко lemma:редко upostag:ADV [12]
#         (deprel:conj) form:имеет lemma:иметь upostag:VERB [20]
#             (deprel:cc) form:но lemma:но upostag:CCONJ [14]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [13]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [15]
#             (deprel:parataxis) form:тем lemma:то upostag:PRON [16]
#                 (deprel:fixed) form:менее lemma:мено upostag:ADV [18]
#                     (deprel:advmod) form:не lemma:не upostag:PART [17]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [19]
#             (deprel:nsubj) form:место lemma:место upostag:NOUN [21]
#                 (deprel:appos) form:Маркова lemma:Марков upostag:PROPN [27]
#                     (deprel:punct) form:( lemma:( upostag:PUNCT [22]
#                     (deprel:parataxis) form:например lemma:например upostag:ADV [23]
#                         (deprel:punct) form:, lemma:, upostag:PUNCT [24]
#                     (deprel:amod) form:Нормальный lemma:нормальный upostag:ADJ [25]
#                     (deprel:amod) form:алгорифм lemma:алгорифй upostag:ADJ [26]
#                     (deprel:punct) form:) lemma:) upostag:PUNCT [28]
#                     (deprel:punct) form:. lemma:. upostag:PUNCT [29]
# (deprel:root) form:писали lemma:писать upostag:VERB [3]
#     (deprel:nsubj) form:часто lemma:часто upostag:NOUN [2]
#         (deprel:amod) form:Ранее lemma:раний upostag:ADJ [1]
#     (deprel:obl) form:алгорифм lemma:алгориф upostag:NOUN [5]
#         (deprel:punct) form:" lemma:" upostag:PUNCT [4]
#         (deprel:punct) form:" lemma:" upostag:PUNCT [6]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [7]
#     (deprel:xcomp) form:используется lemma:использовать upostag:VERB [11]
#         (deprel:advmod) form:сейчас lemma:сейчас upostag:ADV [8]
#         (deprel:nsubj:pass) form:написание lemma:написание upostag:NOUN [10]
#             (deprel:det) form:такое lemma:такой upostag:DET [9]
#         (deprel:advmod) form:редко lemma:редко upostag:ADV [12]
#         (deprel:conj) form:место lemma:место upostag:NOUN [21]
#             (deprel:cc) form:но lemma:но upostag:CCONJ [14]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [13]
#                 (deprel:conj) form:имеет lemma:иметь upostag:VERB [20]
#                     (deprel:punct) form:, lemma:, upostag:PUNCT [15]
#                     (deprel:discourse) form:тем lemma:то upostag:PRON [16]
#                         (deprel:fixed) form:не lemma:не upostag:PART [17]
#                         (deprel:fixed) form:менее lemma:менее upostag:ADV [18]
#                         (deprel:punct) form:, lemma:, upostag:PUNCT [19]
#             (deprel:parataxis) form:например lemma:например upostag:ADV [23]
#                 (deprel:punct) form:( lemma:( upostag:PUNCT [22]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [24]
#             (deprel:nmod) form:алгорифм lemma:алгориф upostag:NOUN [26]
#                 (deprel:amod) form:Нормальный lemma:нормальный upostag:ADJ [25]
#                 (deprel:nmod) form:Маркова lemma:Марков upostag:PROPN [27]
#                 (deprel:punct) form:) lemma:) upostag:PUNCT [28]
#             (deprel:punct) form:. lemma:. upostag:PUNCT [29]
# (deprel:root) form:писали lemma:писать upostag:VERB [3]
#     (deprel:nsubj) form:часто lemma:часто upostag:NOUN [2]
#         (deprel:amod) form:Ранее lemma:раний upostag:ADJ [1]
#     (deprel:obl) form:алгорифм lemma:алгориф upostag:NOUN [5]
#         (deprel:punct) form:" lemma:" upostag:PUNCT [4]
#         (deprel:punct) form:" lemma:" upostag:PUNCT [6]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [7]
#     (deprel:obl) form:используется lemma:использовать upostag:VERB [11]
#         (deprel:advmod) form:сейчас lemma:сейчас upostag:ADV [8]
#         (deprel:nsubj:pass) form:написание lemma:написание upostag:NOUN [10]
#             (deprel:det) form:такое lemma:такой upostag:DET [9]
#         (deprel:advmod) form:редко lemma:редко upostag:ADV [12]
#         (deprel:conj) form:но lemma:но upostag:CCONJ [14]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [13]
#             (deprel:advcl) form:имеет lemma:иметь upostag:VERB [20]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [15]
#                 (deprel:mark) form:тем lemma:то upostag:PRON [16]
#                     (deprel:fixed) form:не lemma:не upostag:PART [17]
#                     (deprel:fixed) form:менее lemma:менее upostag:ADV [18]
#                     (deprel:punct) form:, lemma:, upostag:PUNCT [19]
#                 (deprel:nsubj) form:место lemma:место upostag:NOUN [21]
#                     (deprel:nmod) form:алгорифм lemma:алгориф upostag:NOUN [26]
#                         (deprel:parataxis) form:например lemma:например upostag:ADV [23]
#                             (deprel:punct) form:( lemma:( upostag:PUNCT [22]
#                             (deprel:punct) form:, lemma:, upostag:PUNCT [24]
#                         (deprel:amod) form:Нормальный lemma:нормальный upostag:ADJ [25]
#                         (deprel:appos) form:Маркова lemma:Марков upostag:PROPN [27]
#                             (deprel:punct) form:) lemma:) upostag:PUNCT [28]
#                             (deprel:punct) form:. lemma:. upostag:PUNCT [29]
# # sent_id = 7
# # text = Часто в качестве исполнителя выступает некоторый механизм (компьютер, токарный станок, швейная машина), но понятие алгоритма необязательно относится к компьютерным программам, так, например, чётко описанный рецепт приготовления блюда также является алгоритмом, в таком случае исполнителем является человек.
# 1	Часто	часто	ADV	_	Degree=Pos	5	advmod	_	_
# 2	в	в	ADP	_	_	4	case	_	_
# 3	качестве	качество	NOUN	_	Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing	2	fixed	_	_
# 4	исполнителя	исполнитель	NOUN	_	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	5	obl	_	_
# 5	выступает	выступать	VERB	_	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	0	root	_	SpacesAfter=\n
# 6	некоторый	некоторый	ADJ	_	Case=Nom|Degree=Pos|Gender=Masc|Number=Sing	7	amod	_	_
# 7	механизм	механизм	NOUN	_	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	5	nsubj	_	_
# 8	(	(	PUNCT	_	_	9	punct	_	SpaceAfter=No
# 9	компьютер	компьютер	NOUN	_	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	7	appos	_	SpaceAfter=No
# 10	,	,	PUNCT	_	_	9	punct	_	_
# 11	токарный	токарный	ADJ	_	Case=Nom|Degree=Pos|Gender=Masc|Number=Sing	12	amod	_	_
# 12	станок	станок	NOUN	_	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	5	nsubj	_	SpaceAfter=No
# 13	,	,	PUNCT	_	_	15	punct	_	_
# 14	швейная	швейный	ADJ	_	Case=Nom|Degree=Pos|Gender=Fem|Number=Sing	15	amod	_	_
# 15	машина	машина	NOUN	_	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	5	conj	_	SpaceAfter=No
# 16	)	)	PUNCT	_	_	15	punct	_	SpaceAfter=No
# 17	,	,	PUNCT	_	_	22	punct	_	_
# 18	но	но	CCONJ	_	_	22	cc	_	_
# 19	понятие	понятие	ADV	_	Degree=Pos	22	advmod	_	SpacesAfter=\n
# 20	алгоритма	алгоритма	ADV	_	Degree=Pos	22	advmod	_	_
# 21	необязательно	необязательно	ADV	_	Degree=Pos	22	advmod	_	_
# 22	относится	относиться	VERB	_	Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Mid	5	conj	_	_
# 23	к	к	ADP	_	_	25	case	_	_
# 24	компьютерным	компьютерный	ADJ	_	Case=Dat|Degree=Pos|Number=Plur	25	amod	_	_
# ...
#             (deprel:punct) form:, lemma:, upostag:PUNCT [11]
#             (deprel:iobj) form:им lemma:они upostag:PRON [12]
#             (deprel:nsubj) form:купцы lemma:купец upostag:NOUN [15]
#                 (deprel:cc) form:и lemma:и upostag:CCONJ [14]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [16]
#             (deprel:conj) form:менялы lemma:менял upostag:NOUN [18]
#                 (deprel:cc) form:и lemma:и upostag:CCONJ [17]
#     (deprel:conj) form:учёные lemma:учёный upostag:ADJ [21]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [19]
#         (deprel:cc) form:и lemma:и upostag:CCONJ [20]
#         (deprel:punct) form:. lemma:. upostag:PUNCT [22]
# (deprel:root) form:века lemma:век upostag:NOUN [2]
#     (deprel:nummod) form:Многие lemma:много upostag:NUM [1]
#     (deprel:advmod) form:фактически lemma:фактически upostag:ADV [5]
#         (deprel:nsubj) form:абак lemma:абак upostag:NOUN [3]
#         (deprel:cop) form:был lemma:быть upostag:AUX [4]
#         (deprel:obl) form:средством lemma:средств upostag:NOUN [7]
#             (deprel:amod) form:единственным lemma:единственный upostag:ADJ [6]
#             (deprel:nmod) form:вычислений lemma:вычисление upostag:NOUN [10]
#                 (deprel:case) form:для lemma:для upostag:ADP [8]
#                 (deprel:amod) form:практичных lemma:практичный upostag:ADJ [9]
#         (deprel:conj) form:пользовались lemma:пользоватись upostag:VERB [13]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [11]
#             (deprel:iobj) form:им lemma:они upostag:PRON [12]
#             (deprel:nsubj) form:купцы lemma:купец upostag:NOUN [15]
#                 (deprel:cc) form:и lemma:и upostag:CCONJ [14]
#                 (deprel:conj) form:менялы lemma:менял upostag:NOUN [18]
#                     (deprel:punct) form:, lemma:, upostag:PUNCT [16]
#                     (deprel:cc) form:и lemma:и upostag:CCONJ [17]
#         (deprel:conj) form:учёные lemma:учёный upostag:ADJ [21]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [19]
#             (deprel:cc) form:и lemma:и upostag:CCONJ [20]
#             (deprel:punct) form:. lemma:. upostag:PUNCT [22]
# (deprel:root) form:средством lemma:средство upostag:NOUN [7]
#     (deprel:obl) form:века lemma:век upostag:NOUN [2]
#         (deprel:nummod) form:Многие lemma:много upostag:NUM [1]
#     (deprel:nsubj) form:абак lemma:абак upostag:NOUN [3]
#     (deprel:cop) form:был lemma:быть upostag:AUX [4]
#     (deprel:amod) form:единственным lemma:единственный upostag:ADJ [6]
#         (deprel:obl) form:фактически lemma:фактически upostag:ADV [5]
#     (deprel:nmod) form:вычислений lemma:вычисление upostag:NOUN [10]
#         (deprel:case) form:для lemma:для upostag:ADP [8]
#         (deprel:amod) form:практичных lemma:практичный upostag:ADJ [9]
#         (deprel:conj) form:пользовались lemma:пользоватись upostag:VERB [13]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [11]
#             (deprel:nsubj) form:им lemma:они upostag:PRON [12]
#             (deprel:conj) form:купцы lemma:купец upostag:NOUN [15]
#                 (deprel:cc) form:и lemma:и upostag:CCONJ [14]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [16]
#         (deprel:conj) form:менялы lemma:менял upostag:NOUN [18]
#             (deprel:cc) form:и lemma:и upostag:CCONJ [17]
#         (deprel:conj) form:учёные lemma:учёный upostag:ADJ [21]
#             (deprel:punct) form:, lemma:, upostag:PUNCT [19]
#             (deprel:cc) form:и lemma:и upostag:CCONJ [20]
#             (deprel:punct) form:. lemma:. upostag:PUNCT [22]
# # sent_id = 90
# # text = Достоинства вычислений на счётной доске разъяснял в своих сочинениях такой выдающийся мыслитель, как Герберт Аврилакский (938-1003), ставший в 999 г. папой римским под именем Сильвестра II.
# 1	Достоинства	Достоинство	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	6	nsubj	_	SpacesAfter=\n
# 2	вычислений	вычисление	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur	1	nmod	_	_
# 3	на	на	ADP	_	_	5	case	_	_
# 4	счётной	счётный	ADJ	_	Case=Loc|Degree=Pos|Gender=Fem|Number=Sing	5	amod	_	_
# 5	доске	доска	NOUN	_	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	2	nmod	_	_
# 6	разъяснял	разъяснять	VERB	_	Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act	0	root	_	_
# 7	в	в	ADP	_	_	9	case	_	_
# 8	своих	свой	DET	_	Case=Loc|Number=Plur	9	det	_	_
# 9	сочинениях	сочинения	NOUN	_	Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur	6	obl	_	_
# 10	такой	такой	DET	_	Case=Nom|Gender=Masc|Number=Sing	12	det	_	_
# 11	выдающийся	выдаться	VERB	_	Aspect=Imp|Case=Nom|Gender=Masc|Number=Sing|Tense=Pres|VerbForm=Part|Voice=Mid	12	acl	_	SpacesAfter=\n
# 12	мыслитель	мыслитель	NOUN	_	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	6	nsubj	_	SpaceAfter=No
# 13	,	,	PUNCT	_	_	15	punct	_	_
# 14	как	как	SCONJ	_	_	15	mark	_	_
# 15	Герберт	Герберт	NOUN	_	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	6	advcl	_	_
# 16	Аврилакский	Аврилакский	PROPN	_	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	15	appos	_	_
# 17	(	(	PUNCT	_	_	18	punct	_	SpaceAfter=No
# 18	938	938	NUM	_	_	16	nummod	_	SpaceAfter=No
# 19	-	-	PUNCT	_	_	18	punct	_	SpaceAfter=No
# 20	1003	1003	NUM	_	_	15	nummod	_	SpaceAfter=No
# 21	)	)	PUNCT	_	_	15	punct	_	SpaceAfter=No
# 22	,	,	PUNCT	_	_	23	punct	_	_
# 23	ставший	стать	VERB	_	Aspect=Perf|Case=Nom|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Act	6	acl	_	_
# 24	в	в	ADP	_	_	26	case	_	_
# 25	999	999	NUM	_	_	26	nummod	_	_
# 26	г	год	NOUN	_	Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing	23	obl	_	SpaceAfter=No
# 27	.	.	PUNCT	_	_	23	punct	_	_
# 28	папой	папий	ADJ	_	Case=Ins|Degree=Pos|Gender=Fem|Number=Sing	29	amod	_	_
# 29	римским	римский	NOUN	_	Animacy=Anim|Case=Ins|Gender=Masc|Number=Sing	6	obl	_	SpacesAfter=\n
# 30	под	под	ADP	_	_	31	case	_	_
# 31	именем	имеонь	NOUN	_	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	29	nmod	_	_
# 32	Сильвестра	Сильвестер	NOUN	_	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	31	nmod	_	_
# 33	II	Ii	NUM	_	_	32	nummod	_	SpaceAfter=No
# 34	.	.	PUNCT	_	_	6	punct	_	_
#
#
# (deprel:root) form:разъяснял lemma:разъяснять upostag:VERB [6]
#     (deprel:nsubj) form:Достоинства lemma:Достоинство upostag:NOUN [1]
#         (deprel:nmod) form:вычислений lemma:вычисление upostag:NOUN [2]
#             (deprel:nmod) form:доске lemma:доска upostag:NOUN [5]
#                 (deprel:case) form:на lemma:на upostag:ADP [3]
#                 (deprel:amod) form:счётной lemma:счётный upostag:ADJ [4]
#     (deprel:obl) form:сочинениях lemma:сочинения upostag:NOUN [9]
#         (deprel:case) form:в lemma:в upostag:ADP [7]
#         (deprel:det) form:своих lemma:свой upostag:DET [8]
#     (deprel:nsubj) form:мыслитель lemma:мыслитель upostag:NOUN [12]
#         (deprel:det) form:такой lemma:такой upostag:DET [10]
#         (deprel:acl) form:выдающийся lemma:выдаться upostag:VERB [11]
#     (deprel:advcl) form:Герберт lemma:Герберт upostag:NOUN [15]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [13]
#         (deprel:mark) form:как lemma:как upostag:SCONJ [14]
#         (deprel:appos) form:Аврилакский lemma:Аврилакский upostag:PROPN [16]
#             (deprel:nummod) form:938 lemma:938 upostag:NUM [18]
#                 (deprel:punct) form:( lemma:( upostag:PUNCT [17]
#                 (deprel:punct) form:- lemma:- upostag:PUNCT [19]
#         (deprel:nummod) form:1003 lemma:1003 upostag:NUM [20]
#         (deprel:punct) form:) lemma:) upostag:PUNCT [21]
#     (deprel:acl) form:ставший lemma:стать upostag:VERB [23]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [22]
#         (deprel:obl) form:г lemma:год upostag:NOUN [26]
#             (deprel:case) form:в lemma:в upostag:ADP [24]
#             (deprel:nummod) form:999 lemma:999 upostag:NUM [25]
#         (deprel:punct) form:. lemma:. upostag:PUNCT [27]
#     (deprel:obl) form:римским lemma:римский upostag:NOUN [29]
#         (deprel:amod) form:папой lemma:папий upostag:ADJ [28]
#         (deprel:nmod) form:именем lemma:имеонь upostag:NOUN [31]
#             (deprel:case) form:под lemma:под upostag:ADP [30]
#             (deprel:nmod) form:Сильвестра lemma:Сильвестер upostag:NOUN [32]
#                 (deprel:nummod) form:II lemma:Ii upostag:NUM [33]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [34]
# (deprel:root) form:разъяснял lemma:разъяснять upostag:VERB [6]
#     (deprel:nsubj) form:Достоинства lemma:Достоинство upostag:NOUN [1]
#         (deprel:nmod) form:вычислений lemma:вычисление upostag:NOUN [2]
#             (deprel:nmod) form:доске lemma:доска upostag:NOUN [5]
#                 (deprel:case) form:на lemma:на upostag:ADP [3]
#                 (deprel:amod) form:счётной lemma:счётный upostag:ADJ [4]
#     (deprel:obl) form:сочинениях lemma:сочинения upostag:NOUN [9]
#         (deprel:case) form:в lemma:в upostag:ADP [7]
#         (deprel:det) form:своих lemma:свой upostag:DET [8]
#     (deprel:obj) form:мыслитель lemma:мыслитель upostag:NOUN [12]
#         (deprel:det) form:такой lemma:такой upostag:DET [10]
#         (deprel:amod) form:выдающийся lemma:выдаться upostag:VERB [11]
#         (deprel:parataxis) form:Аврилакский lemma:Аврилакский upostag:ADJ [16]
#             (deprel:nsubj) form:Герберт lemma:Герберт upostag:NOUN [15]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [13]
#                 (deprel:mark) form:как lemma:как upostag:SCONJ [14]
#             (deprel:parataxis) form:938 lemma:938 upostag:NUM [18]
#                 (deprel:punct) form:( lemma:( upostag:PUNCT [17]
#                 (deprel:nummod) form:1003 lemma:1003 upostag:NUM [20]
#                     (deprel:punct) form:- lemma:- upostag:PUNCT [19]
#                     (deprel:conj) form:ставший lemma:стать upostag:VERB [23]
#                         (deprel:punct) form:) lemma:) upostag:PUNCT [21]
#                         (deprel:punct) form:, lemma:, upostag:PUNCT [22]
#                         (deprel:obl) form:г lemma:год upostag:NOUN [26]
#                             (deprel:case) form:в lemma:в upostag:ADP [24]
#                             (deprel:nummod) form:999 lemma:999 upostag:NUM [25]
#                             (deprel:punct) form:. lemma:. upostag:PUNCT [27]
#                             (deprel:nmod) form:римским lemma:римский upostag:NOUN [29]
#                                 (deprel:amod) form:папой lemma:папий upostag:ADJ [28]
#                                 (deprel:nmod) form:именем lemma:имеонь upostag:NOUN [31]
#                                     (deprel:case) form:под lemma:под upostag:ADP [30]
#                                     (deprel:nmod) form:Сильвестра lemma:Сильвестер upostag:NOUN [32]
#                                         (deprel:nummod) form:II lemma:Ii upostag:NUM [33]
#                         (deprel:punct) form:. lemma:. upostag:PUNCT [34]
# (deprel:root) form:разъяснял lemma:разъяснять upostag:VERB [6]
#     (deprel:nsubj) form:Достоинства lemma:Достоинство upostag:NOUN [1]
#         (deprel:nmod) form:вычислений lemma:вычисление upostag:NOUN [2]
#             (deprel:nmod) form:доске lemma:доска upostag:NOUN [5]
#                 (deprel:case) form:на lemma:на upostag:ADP [3]
#                 (deprel:amod) form:счётной lemma:счётный upostag:ADJ [4]
#     (deprel:obl) form:сочинениях lemma:сочинения upostag:NOUN [9]
#         (deprel:case) form:в lemma:в upostag:ADP [7]
#         (deprel:det) form:своих lemma:свой upostag:DET [8]
#     (deprel:obj) form:мыслитель lemma:мыслитель upostag:NOUN [12]
#         (deprel:det) form:такой lemma:такой upostag:DET [10]
#         (deprel:amod) form:выдающийся lemma:выдаться upostag:VERB [11]
#         (deprel:acl:relcl) form:Аврилакский lemma:Аврилакский upostag:ADJ [16]
#             (deprel:nsubj) form:Герберт lemma:Герберт upostag:NOUN [15]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [13]
#                 (deprel:mark) form:как lemma:как upostag:SCONJ [14]
#             (deprel:parataxis) form:938 lemma:938 upostag:NUM [18]
#                 (deprel:punct) form:( lemma:( upostag:PUNCT [17]
#                 (deprel:nummod) form:1003 lemma:1003 upostag:NUM [20]
#                     (deprel:punct) form:- lemma:- upostag:PUNCT [19]
#                 (deprel:punct) form:) lemma:) upostag:PUNCT [21]
#                 (deprel:conj) form:ставший lemma:стать upostag:VERB [23]
#                     (deprel:punct) form:, lemma:, upostag:PUNCT [22]
#                     (deprel:obl) form:г lemma:год upostag:NOUN [26]
#                         (deprel:case) form:в lemma:в upostag:ADP [24]
#                         (deprel:nummod) form:999 lemma:999 upostag:NUM [25]
#                     (deprel:punct) form:. lemma:. upostag:PUNCT [27]
#                     (deprel:obl) form:папой lemma:папа upostag:NOUN [28]
#                     (deprel:obl) form:римским lemma:римский upostag:ADJ [29]
#                         (deprel:obl) form:именем lemma:имеонь upostag:NOUN [31]
#                             (deprel:case) form:под lemma:под upostag:ADP [30]
#                             (deprel:nmod) form:Сильвестра lemma:Сильвестер upostag:NOUN [32]
#                             (deprel:nummod) form:II lemma:Ii upostag:NUM [33]
#                         (deprel:punct) form:. lemma:. upostag:PUNCT [34]
# # sent_id = 91
# # text = Новое с огромным трудом пробивало себе дорогу, и в историю мате
# 1	Новое	новый	ADJ	_	Case=Nom|Degree=Pos|Gender=Neut|Number=Sing	5	nsubj	_	_
# 2	с	с	ADP	_	_	4	case	_	_
# 3	огромным	огромный	ADJ	_	Case=Ins|Degree=Pos|Gender=Neut|Number=Sing	4	amod	_	_
# 4	трудом	трудо	NOUN	_	Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing	5	obl	_	_
# 5	пробивало	пробивать	VERB	_	Aspect=Imp|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act	0	root	_	_
# 6	себе	себя	PRON	_	Case=Dat	7	obl	_	_
# 7	дорогу	дорог	NOUN	_	Animacy=Inan|Case=Dat|Gender=Masc|Number=Sing	5	iobj	_	SpaceAfter=No
# 8	,	,	PUNCT	_	_	11	punct	_	_
# 9	и	и	CCONJ	_	_	11	cc	_	_
# 10	в	в	ADP	_	_	11	case	_	SpacesAfter=\n
# 11	историю	история	NOUN	_	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	5	conj	_	_
# 12	мате	мата	NOUN	_	Animacy=Inan|Case=Dat|Gender=Fem|Number=Sing	11	nmod	_	SpaceAfter=No
#
#
# (deprel:root) form:пробивало lemma:пробивать upostag:VERB [5]
#     (deprel:nsubj) form:Новое lemma:новый upostag:ADJ [1]
#     (deprel:obl) form:трудом lemma:трудо upostag:NOUN [4]
#         (deprel:case) form:с lemma:с upostag:ADP [2]
#         (deprel:amod) form:огромным lemma:огромный upostag:ADJ [3]
#     (deprel:iobj) form:дорогу lemma:дорог upostag:NOUN [7]
#         (deprel:obl) form:себе lemma:себя upostag:PRON [6]
#     (deprel:conj) form:историю lemma:история upostag:NOUN [11]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [8]
#         (deprel:cc) form:и lemma:и upostag:CCONJ [9]
#         (deprel:case) form:в lemma:в upostag:ADP [10]
#         (deprel:nmod) form:мате lemma:мата upostag:NOUN [12]
# (deprel:root) form:пробивало lemma:пробивать upostag:VERB [5]
#     (deprel:obl) form:Новое lemma:новый upostag:ADJ [1]
#     (deprel:obl) form:трудом lemma:трудо upostag:NOUN [4]
#         (deprel:case) form:с lemma:с upostag:ADP [2]
#         (deprel:amod) form:огромным lemma:огромный upostag:ADJ [3]
#     (deprel:iobj) form:себе lemma:себя upostag:PRON [6]
#     (deprel:obl) form:дорогу lemma:дорог upostag:NOUN [7]
#     (deprel:conj) form:мате lemma:мать upostag:VERB [12]
#         (deprel:punct) form:, lemma:, upostag:PUNCT [8]
#         (deprel:cc) form:и lemma:и upostag:CCONJ [9]
#         (deprel:obl) form:историю lemma:история upostag:NOUN [11]
#             (deprel:case) form:в lemma:в upostag:ADP [10]
# (deprel:root) form:Новое lemma:новый upostag:ADJ [1]
#     (deprel:csubj) form:пробивало lemma:пробивать upostag:VERB [5]
#         (deprel:obl) form:трудом lemma:труд upostag:NOUN [4]
#             (deprel:case) form:с lemma:с upostag:ADP [2]
#             (deprel:amod) form:огромным lemma:огромный upostag:ADJ [3]
#         (deprel:obj) form:дорогу lemma:дорога upostag:NOUN [7]
#             (deprel:det) form:себе lemma:себя upostag:PRON [6]
#             (deprel:conj) form:мате lemma:мать upostag:VERB [12]
#                 (deprel:punct) form:, lemma:, upostag:PUNCT [8]
#                 (deprel:cc) form:и lemma:и upostag:CCONJ [9]
#                 (deprel:obl) form:историю lemma:история upostag:NOUN [11]
#                     (deprel:case) form:в lemma:в upostag:ADP [10]

# %%
with open('nonproj.txt', 'r', encoding = 'utf-8') as f:
    nonproj = f.read()
    nonproj_projective = conllu.parse(process(model_projective, nonproj))
    print('done with projective parsing')
    nonproj_swap = conllu.parse(process(model_swap, nonproj))
    print('done with swap parsing')
    nonproj_link2 = conllu.parse(process(model_link2, nonproj))
    print('done with link2 parsing')
# Out:
# done with projective parsing
# done with swap parsing
# done with link2 parsing

# %%
for sentproj, sentswap, sentlink2 in zip(nonproj_projective, nonproj_swap, nonproj_link2):
    sentproj.to_tree().print_tree()
    sentswap.to_tree().print_tree()
    sentlink2.to_tree().print_tree()
    print('next one')
# Out:
# (deprel:root) form:любит lemma:любить upostag:VERB [3]
#     (deprel:advmod) form:Пиво lemma:пиво upostag:ADV [1]
#     (deprel:nsubj) form:он lemma:он upostag:PRON [2]
#     (deprel:obj) form:темное lemma:темный upostag:ADJ [4]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [5]
# (deprel:root) form:любит lemma:любить upostag:VERB [3]
#     (deprel:advmod) form:Пиво lemma:пиво upostag:ADV [1]
#     (deprel:nsubj) form:он lemma:он upostag:PRON [2]
#     (deprel:obl) form:темное lemma:темный upostag:ADJ [4]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [5]
# (deprel:root) form:любит lemma:любить upostag:VERB [3]
#     (deprel:advmod) form:Пиво lemma:пиво upostag:ADV [1]
#     (deprel:nsubj) form:он lemma:он upostag:PRON [2]
#     (deprel:obl) form:темное lemma:темный upostag:ADJ [4]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [5]
# next one
# (deprel:root) form:нужно lemma:нужно upostag:ADV [3]
#     (deprel:obj) form:Учителя lemma:Учитель upostag:NOUN [1]
#     (deprel:advmod) form:очень lemma:очень upostag:ADV [2]
#     (deprel:csubj) form:увидеть lemma:видеть upostag:VERB [4]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [5]
# (deprel:root) form:нужно lemma:нужный upostag:ADJ [3]
#     (deprel:nsubj) form:Учителя lemma:учителе upostag:NOUN [1]
#     (deprel:xcomp) form:увидеть lemma:видеть upostag:VERB [4]
#         (deprel:advmod) form:очень lemma:очень upostag:ADV [2]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [5]
# (deprel:root) form:нужно lemma:нужный upostag:ADJ [3]
#     (deprel:nsubj) form:Учителя lemma:учителе upostag:NOUN [1]
#     (deprel:obl) form:очень lemma:очень upostag:ADV [2]
#     (deprel:csubj) form:увидеть lemma:видеть upostag:VERB [4]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [5]
# next one
# (deprel:root) form:мечтают lemma:мечтать upostag:VERB [3]
#     (deprel:advmod) form:Кубок lemma:Кубок upostag:ADV [1]
#     (deprel:nsubj) form:все lemma:все upostag:PART [2]
#     (deprel:xcomp) form:выиграть lemma:выиграть upostag:VERB [4]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [5]
# (deprel:root) form:мечтают lemma:мечтать upostag:VERB [3]
#     (deprel:advmod) form:Кубок lemma:Кубок upostag:ADV [1]
#     (deprel:advmod) form:все lemma:все upostag:PART [2]
#     (deprel:xcomp) form:выиграть lemma:выиграть upostag:VERB [4]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [5]
# (deprel:root) form:мечтают lemma:мечтать upostag:VERB [3]
#     (deprel:advmod) form:Кубок lemma:Кубок upostag:ADV [1]
#     (deprel:advmod) form:все lemma:все upostag:PART [2]
#     (deprel:xcomp) form:выиграть lemma:выиграть upostag:VERB [4]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [5]
# next one
# (deprel:root) form:люди lemma:человек upostag:NOUN [5]
#     (deprel:advmod) form:Очень lemma:очень upostag:ADV [1]
#     (deprel:nsubj) form:они lemma:они upostag:PRON [2]
#         (deprel:amod) form:хорошие lemma:хорошой upostag:ADJ [3]
#     (deprel:cop) form:были lemma:быть upostag:AUX [4]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [6]
# (deprel:root) form:люди lemma:человек upostag:NOUN [5]
#     (deprel:obl) form:Очень lemma:очень upostag:ADV [1]
#     (deprel:nsubj) form:они lemma:они upostag:PRON [2]
#     (deprel:amod) form:хорошие lemma:хорошой upostag:ADJ [3]
#     (deprel:cop) form:были lemma:быть upostag:AUX [4]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [6]
# (deprel:root) form:хорошие lemma:хорошой upostag:ADJ [3]
#     (deprel:advmod) form:Очень lemma:очень upostag:ADV [1]
#         (deprel:obl) form:они lemma:они upostag:PRON [2]
#     (deprel:cop) form:были lemma:быть upostag:AUX [4]
#     (deprel:nsubj) form:люди lemma:человек upostag:NOUN [5]
#     (deprel:punct) form:. lemma:. upostag:PUNCT [6]
# next one
